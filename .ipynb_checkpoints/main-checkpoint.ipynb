# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (26.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.12.1+cpu
# False

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\korisnik\AppData\Local\Programs\Python\Python312\python.exe

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (0.26.0)
# Requirement already satisfied: numpy>=1.24 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-image) (2.4.6)
# Requirement already satisfied: scipy>=1.11.4 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-image) (1.17.1)
# Requirement already satisfied: networkx>=3.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-image) (12.2.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-image) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-image) (2026.6.1)
# Requirement already satisfied: packaging>=21 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-image) (26.2)
# Requirement already satisfied: lazy-loader>=0.4 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-image) (0.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from scipy.ndimage import label
from skimage.measure import euler_number
from IPython.display import HTML
from PIL import Image
import librosa

def threshold_image(image, threshold):
    return (image >= threshold).astype(np.uint8)

def animate_filtration(image, num_frames=30, size=None, cmap="gray", interval=600):
    """
    image: 2D NumPy array
    returns: HTML animation for Jupyter/Colab
    """

    image = np.asarray(image)

    # If RGB image, convert to grayscale
    if image.ndim == 3:
        image = image.mean(axis=2)

    # Optional resize
    if size is not None:
        img = Image.fromarray(image.astype(np.uint8))
        img = img.resize(size)
        image = np.array(img)

    thresholds = np.linspace(image.max(), image.min(), num_frames)

    fig, ax = plt.subplots()

    im = ax.imshow(
        np.zeros_like(image),
        cmap=cmap,
        vmin=0,
        vmax=1
    )

    title = ax.set_title("")
    ax.set_xticks([])
    ax.set_yticks([])

    def update(frame):
        t = thresholds[frame]
        binary = threshold_image(image, t)

        _, beta_0 = label(binary)
        chi = euler_number(binary, connectivity=1)
        beta_1 = beta_0 - chi

        im.set_data(binary)
        title.set_text(
            f"Threshold t = {t:.2f}\n"
            f"β₀ components = {beta_0}, β₁ holes = {beta_1}"
        )

        return [im, title]

    ani = FuncAnimation(
        fig,
        update,
        frames=len(thresholds),
        interval=interval,
        blit=False,
        repeat=True
    )

    plt.close(fig)

    return HTML(ani.to_jshtml())

# %%
# %pip install librosa
# Out:
# Requirement already satisfied: librosa in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (0.11.0)
# Requirement already satisfied: audioread>=2.1.9 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from librosa) (0.65.1)
# Requirement already satisfied: numpy>=1.22.3 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from librosa) (2.4.6)
# Requirement already satisfied: scipy>=1.6.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from librosa) (1.17.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from librosa) (1.9.0)
# Requirement already satisfied: joblib>=1.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from librosa) (5.3.1)
# Requirement already satisfied: soundfile>=0.12.1 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from librosa) (0.14.0)
# Requirement already satisfied: pooch>=1.1 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from librosa) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from librosa) (0.5)
# Requirement already satisfied: msgpack>=1.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from librosa) (1.2.0)
# Requirement already satisfied: packaging in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from lazy_loader>=0.1->librosa) (26.2)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from numba>=0.51.0->librosa) (0.47.0)
# Requirement already satisfied: platformdirs>=2.5.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pooch>=1.1->librosa) (4.10.0)
# Requirement already satisfied: requests>=2.19.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pooch>=1.1->librosa) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2026.6.17)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn>=1.1.0->librosa) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\korisnik\Downloads\topologija_muzika-main\topologija_muzika-main
# ['.gitattributes', '.ipynb_checkpoints', 'data', 'guitar.mp3', 'main-Copy1.ipynb', 'main.ipynb', 'README.md']

# %%
import librosa

y, sr = librosa.load("guitar.mp3", sr=22050)
print(y.shape, sr)
# Out:
# C:\Users\korisnik\AppData\Local\Temp\ipykernel_3620\4001924196.py:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load("guitar.mp3", sr=22050)
# C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     175 try:
# --> 176     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178 except sf.SoundFileRuntimeError as exc:
#     179     # If soundfile failed, try audioread instead
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\audio.py:209, in __soundfile_load(path, offset, duration, dtype)
#     207 else:
#     208     # Otherwise, create the soundfile object
# --> 209     context = sf.SoundFile(path)
#     211 with context as sf_desc:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\soundfile.py:708, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd, compression_level, bitrate_mode)
#     706 self._info = _create_info_struct(file, mode, samplerate, channels,
#     707                                  format, subtype, endian)
# --> 708 self._file = self._open(file, mode_int, closefd)
#     709 if set(mode).issuperset('r+') and self.seekable():
#     710     # Move write position to 0 (like in Python file objects)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\soundfile.py:1296, in SoundFile._open(self, file, mode_int, closefd)
#    1295         err = _snd.sf_error(file_ptr)
# -> 1296         raise LibsndfileError(err, prefix=f"Error opening {self.name!r}: ")
#    1297 if mode_int == _snd.SFM_WRITE:
#    1298     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1299     # when opening a named pipe in SFM_WRITE mode.
#    1300     # See http://github.com/erikd/libsndfile/issues/77.
#
# LibsndfileError: Error opening 'guitar.mp3': File does not exist or is not a regular file (possibly a pipe?).
#
# During handling of the above exception, another exception occurred:
#
# NoBackendError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 import librosa
#       2
# ----> 3 y, sr = librosa.load("guitar.mp3", sr=22050)
#       4 print(y.shape, sr)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\audio.py:184, in load(path, sr, mono, offset, duration, dtype, res_type)
#     180 if isinstance(path, (str, pathlib.PurePath)):
#     181     warnings.warn(
#     182         "PySoundFile failed. Trying audioread instead.", stacklevel=2
#     183     )
# --> 184     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     185 else:
#     186     raise exc
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\decorator\__init__.py:247, in decorate.<locals>.fun(*args, **kw)
#     245 if not kwsyntax:
#     246     args, kw = fix(args, kw, sig)
# --> 247 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\util\decorators.py:63, in deprecated.<locals>.__wrapper(func, *args, **kwargs)
#      54 """Warn the user, and then proceed."""
#      55 warnings.warn(
#      56     "{:s}.{:s}\n\tDeprecated as of librosa version {:s}."
#      57     "\n\tIt will be removed in librosa version {:s}.".format(
#    (...)     61     stacklevel=3,  # Would be 2, but the decorator adds a level
#      62 )
# ---> 63 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\audio.py:240, in __audioread_load(path, offset, duration, dtype)
#     237     reader = path
#     238 else:
#     239     # If the input was not an audioread object, try to open it
# --> 240     reader = audioread.audio_open(path)
#     242 with reader as input_file:
#     243     sr_native = input_file.samplerate
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\audioread\__init__.py:131, in audio_open(path, backends)
#     128         pass
#     130 # All backends failed!
# --> 131 raise NoBackendError()
#
# NoBackendError:

# %%
import os

print(os.getcwd())
print(os.path.exists("guitar.mp3"))
print(os.path.isfile("guitar.mp3"))
print(os.path.getsize("guitar.mp3"))

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt



def compute_log_mel_spectrogram(
    audio_path,
    sr=22050,
    n_fft=2048,
    hop_length=512,
    n_mels=128
):
    y, sr = librosa.load(audio_path, sr=sr, mono=True)

    S = librosa.feature.melspectrogram(
        y=y,
        sr=sr,
        n_fft=n_fft,
        hop_length=hop_length,
        n_mels=n_mels,
        power=2.0
    )

    return librosa.power_to_db(S, ref=np.max)

def plot_log_mel_spectrogram(log_S):
    plt.imshow(log_S, origin="lower", aspect="auto", cmap="magma")
    plt.colorbar(label="dB")
    plt.xlabel("Time frame")
    plt.ylabel("Mel frequency bin")
    plt.title("Log-mel spectrogram")
    plt.show()

log_S = compute_log_mel_spectrogram("guitar.mp3")
print(log_S.shape)  # (frequency_bins, time_frames)
plot_log_mel_spectrogram(log_S)
# Out:
# C:\Users\korisnik\AppData\Local\Temp\ipykernel_3620\3682958928.py:14: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_path, sr=sr, mono=True)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     175 try:
# --> 176     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178 except sf.SoundFileRuntimeError as exc:
#     179     # If soundfile failed, try audioread instead
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\audio.py:209, in __soundfile_load(path, offset, duration, dtype)
#     207 else:
#     208     # Otherwise, create the soundfile object
# --> 209     context = sf.SoundFile(path)
#     211 with context as sf_desc:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\soundfile.py:708, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd, compression_level, bitrate_mode)
#     706 self._info = _create_info_struct(file, mode, samplerate, channels,
#     707                                  format, subtype, endian)
# --> 708 self._file = self._open(file, mode_int, closefd)
#     709 if set(mode).issuperset('r+') and self.seekable():
#     710     # Move write position to 0 (like in Python file objects)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\soundfile.py:1296, in SoundFile._open(self, file, mode_int, closefd)
#    1295         err = _snd.sf_error(file_ptr)
# -> 1296         raise LibsndfileError(err, prefix=f"Error opening {self.name!r}: ")
#    1297 if mode_int == _snd.SFM_WRITE:
#    1298     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1299     # when opening a named pipe in SFM_WRITE mode.
#    1300     # See http://github.com/erikd/libsndfile/issues/77.
#
# LibsndfileError: Error opening 'guitar.mp3': File does not exist or is not a regular file (possibly a pipe?).
#
# During handling of the above exception, another exception occurred:
#
# NoBackendError                            Traceback (most recent call last)
# Cell In[10], line 35
#      31     plt.ylabel("Mel frequency bin")
#      32     plt.title("Log-mel spectrogram")
#      33     plt.show()
#      34
# ---> 35 log_S = compute_log_mel_spectrogram("guitar.mp3")
#      36 print(log_S.shape)  # (frequency_bins, time_frames)
#      37 plot_log_mel_spectrogram(log_S)
#
# Cell In[10], line 14, in compute_log_mel_spectrogram(audio_path, sr, n_fft, hop_length, n_mels)
#      10     n_fft=2048,
#      11     hop_length=512,
#      12     n_mels=128
#      13 ):
# ---> 14     y, sr = librosa.load(audio_path, sr=sr, mono=True)
#      15
#      16     S = librosa.feature.melspectrogram(
#      17         y=y,
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\audio.py:184, in load(path, sr, mono, offset, duration, dtype, res_type)
#     180 if isinstance(path, (str, pathlib.PurePath)):
#     181     warnings.warn(
#     182         "PySoundFile failed. Trying audioread instead.", stacklevel=2
#     183     )
# --> 184     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     185 else:
#     186     raise exc
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\decorator\__init__.py:247, in decorate.<locals>.fun(*args, **kw)
#     245 if not kwsyntax:
#     246     args, kw = fix(args, kw, sig)
# --> 247 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\util\decorators.py:63, in deprecated.<locals>.__wrapper(func, *args, **kwargs)
#      54 """Warn the user, and then proceed."""
#      55 warnings.warn(
#      56     "{:s}.{:s}\n\tDeprecated as of librosa version {:s}."
#      57     "\n\tIt will be removed in librosa version {:s}.".format(
#    (...)     61     stacklevel=3,  # Would be 2, but the decorator adds a level
#      62 )
# ---> 63 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\audio.py:240, in __audioread_load(path, offset, duration, dtype)
#     237     reader = path
#     238 else:
#     239     # If the input was not an audioread object, try to open it
# --> 240     reader = audioread.audio_open(path)
#     242 with reader as input_file:
#     243     sr_native = input_file.samplerate
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\audioread\__init__.py:131, in audio_open(path, backends)
#     128         pass
#     130 # All backends failed!
# --> 131 raise NoBackendError()
#
# NoBackendError:

# %%
animate_filtration(log_S, num_frames=30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 animate_filtration(log_S, num_frames=30)
#
# NameError: name 'log_S' is not defined

# %%
# %pip install gudhi
# Out:
# Requirement already satisfied: gudhi in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gudhi
from gudhi.representations import Landscape
import numpy as np

def compute_persistence(image):
    cubical_complex = gudhi.CubicalComplex(top_dimensional_cells=image)
    cubical_complex.compute_persistence()
    
    h0_diagram = cubical_complex.persistence_intervals_in_dimension(0)
    h1_diagram = cubical_complex.persistence_intervals_in_dimension(1)
    
    
    # Removing infinite deaths, landscapes need finite intervals
    h0_finite = h0_diagram[np.isfinite(h0_diagram[:, 1])]
    h1_finite = h1_diagram[np.isfinite(h1_diagram[:, 1])]
    
    # num_landscapes = number of landscape layers λ1, λ2, ...
    # resolution = number of sample points on the x-axis
    landscape = Landscape(num_landscapes=5, resolution=100)
    
    h0_landscape = landscape.fit_transform([h0_finite])
    h1_landscape = landscape.fit_transform([h1_finite])
    
    return h0_diagram, h1_diagram, h0_landscape, h1_landscape

grid_data = np.random.randint(1, 15, size=(7, 7))
print("Random 7x7 Matrix:")
print(grid_data)

h0_diagram, h1_diagram, h0_landscape, h1_landscape = compute_persistence(grid_data)

print(h0_diagram)
print(h1_diagram)

print("H0 landscape shape:", h0_landscape.shape)
print("H1 landscape shape:", h1_landscape.shape)
#print("H0 landscape vector:\n", h0_landscape)
# Out:
# Random 7x7 Matrix:
# [[ 5  6  8  1  5  3 12]
#  [ 7 14  4  1  6  4  5]
#  [11  1  3  4 13  3 11]
#  [ 6  4 14 11  6  9  3]
#  [ 5  2 14  8  8 10  1]
#  [ 9  2  3 14  5 10  5]
#  [13  4 14  3  5  1  1]]
# [[ 1.  3.]
#  [ 2.  4.]
#  [ 3.  4.]
#  [ 1.  5.]
#  [ 1.  5.]
#  [ 5.  6.]
#  [ 1. inf]]
# [[ 8. 10.]
#  [ 6. 13.]
#  [ 7. 14.]
#  [ 8. 14.]
#  [ 5. 14.]]
# H0 landscape shape: (1, 500)
# H1 landscape shape: (1, 500)

# %%
# %pip install torch
# Out:
# Requirement already satisfied: torch in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (2.12.1+cpu)
# Requirement already satisfied: filelock in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch) (2026.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Pišemo CNN gde možemo da isključimo sloj perzistencije da bi uočili njihov doprinos neuronskoj mreži

# %%
import torch
import torch.nn as nn

num_classes = 2

class AudioClassifier(nn.Module):

    def __init__(self, use_topology=False, topo_dim=1000):
        super().__init__()

        self.use_topology = use_topology

        self.cnn = nn.Sequential(
            nn.Conv2d(1, 16, 3),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(16, 32, 3),
            nn.ReLU(),

            nn.AdaptiveAvgPool2d((4, 4)),
            nn.Flatten()
        )

        self.cnn_summary = nn.Linear(32 * 4 * 4, 128)

        if use_topology:
            self.topo_summary = nn.Sequential(
                nn.Linear(topo_dim, 256),
                nn.ReLU(),
                nn.Dropout(0.2),
                nn.Linear(256, 128),
                nn.ReLU()
            )

            self.classifier = nn.Sequential(
                nn.Linear(256, 128),
                nn.ReLU(),
                nn.Dropout(0.2),
                nn.Linear(128, num_classes)
            )

        else:
            self.classifier = nn.Sequential(
                nn.Linear(128, 64),
                nn.ReLU(),
                nn.Linear(64, num_classes)
            )

    def forward(self, spectrogram, landscape=None):
        cnn_features = self.cnn(spectrogram)
        cnn_features = self.cnn_summary(cnn_features)

        if self.use_topology:
            topo_features = self.topo_summary(landscape)
            x = torch.cat([cnn_features, topo_features], dim=1)
        else:
            x = cnn_features

        return self.classifier(x)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_cnn = AudioClassifier(use_topology=False).to(device)
model_cnn_topo = AudioClassifier(use_topology=True).to(device)

print("Models created.")
# Out:
# Models created.

# %%
from pathlib import Path
import librosa
import numpy as np
import pandas as pd

def create_music_dataset(genres = ["pop", "rock"]):
    records = []

    for label, genre in enumerate(genres):

        genre_path = Path("data/genres") / genre

        for file_path in genre_path.glob("*.wav"):

            spectrogram = compute_log_mel_spectrogram(file_path)

            records.append({
                "file": str(file_path),
                "genre": genre,
                "label": label,
                "spectrogram": spectrogram
            })

    return pd.DataFrame(records)

df = create_music_dataset(["pop", "rock"])
df.head()
# Out:
#                             file genre  label  \
# 0  data\genres\pop\pop.00000.wav   pop      0
# 1  data\genres\pop\pop.00001.wav   pop      0
# 2  data\genres\pop\pop.00002.wav   pop      0
# 3  data\genres\pop\pop.00003.wav   pop      0
# 4  data\genres\pop\pop.00004.wav   pop      0
#
#                                          spectrogram
# 0  [[-10.855934, -7.7729454, -7.574999, -8.024984...
# 1  [[-13.610338, -10.763615, -9.43648, -11.210834...
# 2  [[-20.55059, -17.711145, -17.620384, -17.01046...
# 3  [[-57.03638, -48.159576, -39.160786, -35.00329...
# 4  [[-17.353067, -14.092247, -14.026318, -14.4201...

# %%
print(df.shape)
print(df.columns)
print(df.head())
# Out:
# (200, 4)
# Index(['file', 'genre', 'label', 'spectrogram'], dtype='str')
#                             file genre  label  \
# 0  data\genres\pop\pop.00000.wav   pop      0
# 1  data\genres\pop\pop.00001.wav   pop      0
# 2  data\genres\pop\pop.00002.wav   pop      0
# 3  data\genres\pop\pop.00003.wav   pop      0
# 4  data\genres\pop\pop.00004.wav   pop      0
#
#                                          spectrogram
# 0  [[-10.855934, -7.7729454, -7.574999, -8.024984...
# 1  [[-13.610338, -10.763615, -9.43648, -11.210834...
# 2  [[-20.55059, -17.711145, -17.620384, -17.01046...
# 3  [[-57.03638, -48.159576, -39.160786, -35.00329...
# 4  [[-17.353067, -14.092247, -14.026318, -14.4201...

# %%
print(type(df["spectrogram"].iloc[0]))
print(df["spectrogram"].iloc[0].shape)

print(df["spectrogram"].iloc[1].shape)
print(df["spectrogram"].iloc[2].shape)
# Out:
# <class 'numpy.ndarray'>
# (128, 1293)
# (128, 1293)
# (128, 1293)

# %%
plot_log_mel_spectrogram(df.iloc[0]["spectrogram"])

# %%
def compute_landscapes(spectrogram):
    _, _, h0_landscape, h1_landscape = compute_persistence(spectrogram)
    return np.concatenate([
        h0_landscape.ravel(),
        h1_landscape.ravel()
    ])

df["landscape"] = df["spectrogram"].apply(compute_landscapes)
df.head()
# Out:
#                             file genre  label  \
# 0  data\genres\pop\pop.00000.wav   pop      0
# 1  data\genres\pop\pop.00001.wav   pop      0
# 2  data\genres\pop\pop.00002.wav   pop      0
# 3  data\genres\pop\pop.00003.wav   pop      0
# 4  data\genres\pop\pop.00004.wav   pop      0
#
#                                          spectrogram  \
# 0  [[-10.855934, -7.7729454, -7.574999, -8.024984...
# 1  [[-13.610338, -10.763615, -9.43648, -11.210834...
# 2  [[-20.55059, -17.711145, -17.620384, -17.01046...
# 3  [[-57.03638, -48.159576, -39.160786, -35.00329...
# 4  [[-17.353067, -14.092247, -14.026318, -14.4201...
#
#                                            landscape
# 0  [1.0201813836977898, 2.0403627673955795, 3.060...
# 1  [1.0204814892893668, 2.0409629785787335, 3.061...
# 2  [0.9764181259295324, 1.9528362518590647, 2.929...
# 3  [0.9468413671738353, 1.8936827343476705, 2.840...
# 4  [0.8648988133179216, 1.7297976266358632, 2.594...

# %%
df["landscape"].iloc[0].shape
# Out:
# (1000,)

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\korisnik\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def fix_spectrogram_shape(S, target_frames=130):
    # S je oblika (128, broj_vremenskih_frejmova)
    if S.shape[1] > target_frames:
        return S[:, :target_frames]
    elif S.shape[1] < target_frames:
        pad_width = target_frames - S.shape[1]
        return np.pad(S, ((0, 0), (0, pad_width)), mode="constant")
    else:
        return S

df["spectrogram_fixed"] = df["spectrogram"].apply(fix_spectrogram_shape)

print(df["spectrogram_fixed"].iloc[0].shape)
# Out:
# (128, 130)

# %%
from sklearn.model_selection import train_test_split

X = df[["spectrogram_fixed"]]
y = df[["label"]]

print(X.shape)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42
)

print(X_train.shape)
# Out:
# (200, 1)
# (140, 1)

# %%
model_cnn = AudioClassifier(use_topology=False).to(device)
print("CNN model reset.")
# Out:
# CNN model reset.

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

X_train_tensor = torch.tensor(
    np.stack(X_train["spectrogram_fixed"].values),
    dtype=torch.float32
).unsqueeze(1)

y_train_tensor = torch.tensor(
    y_train["label"].values,
    dtype=torch.long
)

print(X_train_tensor.shape)
print(y_train_tensor.shape)
# Out:
# torch.Size([140, 1, 128, 130])
# torch.Size([140])

# %%
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

train_loader = DataLoader(
    TensorDataset(X_train_tensor, y_train_tensor),
    batch_size=16,
    shuffle=True
)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_cnn.parameters(), lr=0.0005)
epochs = 75

for epoch in range(epochs):
    running_loss = 0.0

    for inputs, labels in train_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model_cnn(inputs)

        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f"Epoch {epoch+1}/{epochs}, Loss: {running_loss / len(train_loader):.4f}")
# Out:
# Epoch 1/75, Loss: 0.8187
# Epoch 2/75, Loss: 0.7921
# Epoch 3/75, Loss: 0.7154
# Epoch 4/75, Loss: 0.6545
# Epoch 5/75, Loss: 0.6508
# Epoch 6/75, Loss: 0.5974
# Epoch 7/75, Loss: 0.5662
# Epoch 8/75, Loss: 0.5201
# Epoch 9/75, Loss: 0.5060
# Epoch 10/75, Loss: 0.5074
# Epoch 11/75, Loss: 0.4295
# Epoch 12/75, Loss: 0.4150
# Epoch 13/75, Loss: 0.4763
# Epoch 14/75, Loss: 0.3920
# Epoch 15/75, Loss: 0.4704
# Epoch 16/75, Loss: 0.4775
# Epoch 17/75, Loss: 0.4065
# Epoch 18/75, Loss: 0.3953
# Epoch 19/75, Loss: 0.3909
# Epoch 20/75, Loss: 0.3675
# Epoch 21/75, Loss: 0.4854
# Epoch 22/75, Loss: 0.4018
# Epoch 23/75, Loss: 0.4128
# Epoch 24/75, Loss: 0.4243
# Epoch 25/75, Loss: 0.3672
# Epoch 26/75, Loss: 0.3828
# Epoch 27/75, Loss: 0.3831
# Epoch 28/75, Loss: 0.3658
# Epoch 29/75, Loss: 0.3259
# Epoch 30/75, Loss: 0.3293
# Epoch 31/75, Loss: 0.2955
# Epoch 32/75, Loss: 0.2773
# Epoch 33/75, Loss: 0.2631
# Epoch 34/75, Loss: 0.2445
# Epoch 35/75, Loss: 0.2534
# Epoch 36/75, Loss: 0.2453
# Epoch 37/75, Loss: 0.2502
# Epoch 38/75, Loss: 0.2954
# Epoch 39/75, Loss: 0.2345
# Epoch 40/75, Loss: 0.2042
# Epoch 41/75, Loss: 0.2816
# Epoch 42/75, Loss: 0.2041
# Epoch 43/75, Loss: 0.2016
# Epoch 44/75, Loss: 0.1969
# Epoch 45/75, Loss: 0.2150
# Epoch 46/75, Loss: 0.2085
# Epoch 47/75, Loss: 0.1914
# Epoch 48/75, Loss: 0.1949
# Epoch 49/75, Loss: 0.1871
# Epoch 50/75, Loss: 0.1590
# Epoch 51/75, Loss: 0.1514
# Epoch 52/75, Loss: 0.1272
# Epoch 53/75, Loss: 0.1185
# Epoch 54/75, Loss: 0.1113
# Epoch 55/75, Loss: 0.1046
# Epoch 56/75, Loss: 0.0899
# Epoch 57/75, Loss: 0.1009
# Epoch 58/75, Loss: 0.1474
# Epoch 59/75, Loss: 0.1374
# Epoch 60/75, Loss: 0.0822
# Epoch 61/75, Loss: 0.1044
# Epoch 62/75, Loss: 0.1187
# Epoch 63/75, Loss: 0.0839
# Epoch 64/75, Loss: 0.1571
# Epoch 65/75, Loss: 0.0831
# Epoch 66/75, Loss: 0.0934
# Epoch 67/75, Loss: 0.0831
# Epoch 68/75, Loss: 0.0557
# Epoch 69/75, Loss: 0.0464
# Epoch 70/75, Loss: 0.0480
# Epoch 71/75, Loss: 0.0586
# Epoch 72/75, Loss: 0.0866
# Epoch 73/75, Loss: 0.0597
# Epoch 74/75, Loss: 0.0526
# Epoch 75/75, Loss: 0.0729

# %%
X_test_tensor = torch.tensor(
    np.stack(X_test["spectrogram_fixed"].values),
    dtype=torch.float32
).unsqueeze(1)

y_test_tensor = torch.tensor(
    y_test["label"].values,
    dtype=torch.long
)

test_loader = DataLoader(
    TensorDataset(X_test_tensor, y_test_tensor),
    batch_size=16,
    shuffle=False
)

print(X_test_tensor.shape)
print(y_test_tensor.shape)
# Out:
# torch.Size([60, 1, 128, 130])
# torch.Size([60])

# %%
model_cnn.eval()

correct = 0
total = 0

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model_cnn(inputs)
        predicted = torch.argmax(outputs, dim=1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

cnn_accuracy = correct / total

print(f"CNN accuracy: {cnn_accuracy:.4f}")
# Out:
# CNN accuracy: 0.9667

# %%
X_topo = df[["spectrogram_fixed", "landscape"]]
y_topo = df[["label"]]

X_topo_train, X_topo_test, y_topo_train, y_topo_test = train_test_split(
    X_topo,
    y_topo,
    test_size=0.3,
    random_state=42
)

X_train_spectro_tensor = torch.tensor(
    np.stack(X_topo_train["spectrogram_fixed"].values),
    dtype=torch.float32
).unsqueeze(1)

landscape_train_np = np.stack(X_topo_train["landscape"].values)
landscape_test_np = np.stack(X_topo_test["landscape"].values)

landscape_mean = landscape_train_np.mean(axis=0)
landscape_std = landscape_train_np.std(axis=0) + 1e-8

landscape_train_np = (landscape_train_np - landscape_mean) / landscape_std
landscape_test_np = (landscape_test_np - landscape_mean) / landscape_std

X_train_landscape_tensor = torch.tensor(
    landscape_train_np,
    dtype=torch.float32
)

y_train_topo_tensor = torch.tensor(
    y_topo_train["label"].values,
    dtype=torch.long
)

print(X_train_spectro_tensor.shape)
print(X_train_landscape_tensor.shape)
print(y_train_topo_tensor.shape)
# Out:
# torch.Size([140, 1, 128, 130])
# torch.Size([140, 1000])
# torch.Size([140])

# %%
model_cnn_topo = AudioClassifier(use_topology=True).to(device)
print("Topology model reset.")
# Out:
# Topology model reset.

# %%
train_topo_loader = DataLoader(
    TensorDataset(
        X_train_spectro_tensor,
        X_train_landscape_tensor,
        y_train_topo_tensor
    ),
    batch_size=16,
    shuffle=True
)

criterion = nn.CrossEntropyLoss()
optimizer_topo = optim.Adam(model_cnn_topo.parameters(), lr=0.0003)
epochs = 75

for epoch in range(epochs):
    running_loss = 0.0

    for spectrograms, landscapes, labels in train_topo_loader:
        spectrograms = spectrograms.to(device)
        landscapes = landscapes.to(device)
        labels = labels.to(device)

        optimizer_topo.zero_grad()

        outputs = model_cnn_topo(spectrograms, landscapes)

        loss = criterion(outputs, labels)

        loss.backward()
        optimizer_topo.step()

        running_loss += loss.item()

    print(f"Epoch {epoch+1}/{epochs}, Loss: {running_loss / len(train_topo_loader):.4f}")
# Out:
# Epoch 1/75, Loss: 0.7906
# Epoch 2/75, Loss: 0.5620
# Epoch 3/75, Loss: 0.4532
# Epoch 4/75, Loss: 0.3616
# Epoch 5/75, Loss: 0.3185
# Epoch 6/75, Loss: 0.2643
# Epoch 7/75, Loss: 0.2415
# Epoch 8/75, Loss: 0.2015
# Epoch 9/75, Loss: 0.1705
# Epoch 10/75, Loss: 0.1471
# Epoch 11/75, Loss: 0.1216
# Epoch 12/75, Loss: 0.0851
# Epoch 13/75, Loss: 0.0682
# Epoch 14/75, Loss: 0.0515
# Epoch 15/75, Loss: 0.0339
# Epoch 16/75, Loss: 0.0202
# Epoch 17/75, Loss: 0.0181
# Epoch 18/75, Loss: 0.0122
# Epoch 19/75, Loss: 0.0117
# Epoch 20/75, Loss: 0.0049
# Epoch 21/75, Loss: 0.0038
# Epoch 22/75, Loss: 0.0041
# Epoch 23/75, Loss: 0.0024
# Epoch 24/75, Loss: 0.0022
# Epoch 25/75, Loss: 0.0024
# Epoch 26/75, Loss: 0.0016
# Epoch 27/75, Loss: 0.0011
# Epoch 28/75, Loss: 0.0017
# Epoch 29/75, Loss: 0.0012
# Epoch 30/75, Loss: 0.0010
# Epoch 31/75, Loss: 0.0011
# Epoch 32/75, Loss: 0.0009
# Epoch 33/75, Loss: 0.0012
# Epoch 34/75, Loss: 0.0005
# Epoch 35/75, Loss: 0.0014
# Epoch 36/75, Loss: 0.0006
# Epoch 37/75, Loss: 0.0010
# Epoch 38/75, Loss: 0.0004
# Epoch 39/75, Loss: 0.0005
# Epoch 40/75, Loss: 0.0009
# Epoch 41/75, Loss: 0.0007
# Epoch 42/75, Loss: 0.0003
# Epoch 43/75, Loss: 0.0003
# Epoch 44/75, Loss: 0.0003
# Epoch 45/75, Loss: 0.0003
# Epoch 46/75, Loss: 0.0004
# Epoch 47/75, Loss: 0.0004
# Epoch 48/75, Loss: 0.0002
# Epoch 49/75, Loss: 0.0002
# Epoch 50/75, Loss: 0.0004
# Epoch 51/75, Loss: 0.0003
# Epoch 52/75, Loss: 0.0002
# Epoch 53/75, Loss: 0.0002
# Epoch 54/75, Loss: 0.0002
# Epoch 55/75, Loss: 0.0002
# Epoch 56/75, Loss: 0.0003
# Epoch 57/75, Loss: 0.0002
# Epoch 58/75, Loss: 0.0002
# Epoch 59/75, Loss: 0.0002
# Epoch 60/75, Loss: 0.0002
# Epoch 61/75, Loss: 0.0001
# Epoch 62/75, Loss: 0.0001
# Epoch 63/75, Loss: 0.0001
# Epoch 64/75, Loss: 0.0011
# Epoch 65/75, Loss: 0.0011
# Epoch 66/75, Loss: 0.0004
# Epoch 67/75, Loss: 0.0002
# Epoch 68/75, Loss: 0.0005
# Epoch 69/75, Loss: 0.0001
# Epoch 70/75, Loss: 0.0002
# Epoch 71/75, Loss: 0.0001
# Epoch 72/75, Loss: 0.0003
# Epoch 73/75, Loss: 0.0002
# Epoch 74/75, Loss: 0.0002
# Epoch 75/75, Loss: 0.0001

# %%
X_test_spectro_tensor = torch.tensor(
    np.stack(X_topo_test["spectrogram_fixed"].values),
    dtype=torch.float32
).unsqueeze(1)

X_test_landscape_tensor = torch.tensor(
    landscape_test_np,
    dtype=torch.float32
)

y_test_topo_tensor = torch.tensor(
    y_topo_test["label"].values,
    dtype=torch.long
)

test_topo_loader = DataLoader(
    TensorDataset(
        X_test_spectro_tensor,
        X_test_landscape_tensor,
        y_test_topo_tensor
    ),
    batch_size=16,
    shuffle=False
)

model_cnn_topo.eval()

correct = 0
total = 0

with torch.no_grad():
    for spectrograms, landscapes, labels in test_topo_loader:
        spectrograms = spectrograms.to(device)
        landscapes = landscapes.to(device)
        labels = labels.to(device)

        outputs = model_cnn_topo(spectrograms, landscapes)
        predicted = torch.argmax(outputs, dim=1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

topo_accuracy = correct / total

print(f"CNN + topology accuracy: {topo_accuracy:.4f}")
# Out:
# CNN + topology accuracy: 0.9000
